# %%
from data import data
# Out:
# /Users/christinexu/Desktop/DSC/ucsd_dsc/DSC180/quarter2/test_run/data/data.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlg_foodcom['id'] = id_lst
# /Users/christinexu/Desktop/DSC/ucsd_dsc/DSC180/quarter2/test_run/data/data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlg_foodcom['title'] = nlg_foodcom['title'].str.lower()

# %%
data.combined_foodcom
# Out:
#                                                 name      id  minutes  \
# 0         arriba   baked winter squash mexican style  137739       55
# 1                   a bit different  breakfast pizza   31490       30
# 2                          all in the kitchen  chili  112140      130
# 3                                 alouette  potatoes   59389       45
# 4                 amish  tomato ketchup  for canning   44061      190
# ...                                              ...     ...      ...
# 226886                                   zydeco soup  486161       60
# 226887                              zydeco spice mix  493372        5
# 226888                     zydeco ya ya deviled eggs  308080       40
# 226889        cookies by design   cookies on a stick  298512       29
# 226890  cookies by design   sugar shortbread cookies  298509       20
#
#         contributor_id   submitted  \
# 0                47892  2005-09-16
# 1                26278  2002-06-17
# ...

# %%
# !python final.py
# Out:
# /Users/christinexu/Desktop/DSC/ucsd_dsc/DSC180/quarter2/test_run/data/data.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlg_foodcom['id'] = id_lst
# /Users/christinexu/Desktop/DSC/ucsd_dsc/DSC180/quarter2/test_run/data/data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlg_foodcom['title'] = nlg_foodcom['title'].str.lower()
# Please input the photo of your available ingredeints!
# Traceback (most recent call last):
# ...

# %%
# !pip install openai

# %%
from input_image import read_image

# %%
 read_image.ingredient_identifier('image1.jpg')

# %%
out
# Out:
# {'id': 'chatcmpl-8pjJRaV9o9fUwJxcJGCyCOCuOpF3Y',
#  'object': 'chat.completion',
#  'created': 1707339601,
#  'model': 'gpt-4-1106-vision-preview',
#  'usage': {'prompt_tokens': 282, 'completion_tokens': 95, 'total_tokens': 377},
#  'choices': [{'message': {'role': 'assistant',
#     'content': '```json\n{\n  "ingredients": [\n    "Beef Shank",\n    "Celery",\n    "Carrots",\n    "Onions",\n    "Garlic",\n    "Bay Leaf",\n    "Fresh Thyme",\n    "Canned Tomatoes",\n    "White Wine",\n    "Parmesan Cheese",\n    "Baguette",\n    "Salt",\n    "Ground Black Pepper",\n    "Butter",\n    "Tomato Paste"\n  ]\n}\n```'},
#    'finish_reason': 'stop',
#    'index': 0}]}

# %%
json.loads(out['choices'][0]['message']['content'].strip('` \n').strip('json\n'))['ingredients']
# Out:
# ['beef shank',
#  'celery',
#  'carrots',
#  'onions',
#  'garlic',
#  'bay leaf',
#  'fresh thyme',
#  'olive oil',
#  'white wine',
#  'lard',
#  'salt',
#  'black peppercorns',
#  'bread',
#  'tomato paste']

# %%
json_string_inside = out['choices'][0]['message']['content']

parsed_data = json.loads(json_string_inside)

# Extract the ingredients list
ingredients_list_inside = parsed_data["ingredients"]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/m1/rwxd3g8d2zl60slvhbm1p89w0000gn/T/ipykernel_16198/2515956594.py in <module>
#       1 json_string_inside = out['choices'][0]['message']['content']
#       2
# ----> 3 parsed_data = json.loads(json_string_inside)
#       4
#       5 # Extract the ingredients list
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
json.loads('{\n  "ingredients": [\n    "Beef Shank",\n    "Celery",\n    "Carrots",\n    "Onions",\n    "Garlic",\n    "Bay Leaf",\n    "Fresh Thyme",\n    "Olive Oil",\n    "Butter",\n    "Baguette",\n    "Salt",\n    "Black Pepper",\n    "Tomato Paste"\n  ]\n}')
# Out:
# {'ingredients': ['Beef Shank',
#   'Celery',
#   'Carrots',
#   'Onions',
#   'Garlic',
#   'Bay Leaf',
#   'Fresh Thyme',
#   'Olive Oil',
#   'Butter',
#   'Baguette',
#   'Salt',
#   'Black Pepper',
#   'Tomato Paste']}

# %%
json.loads(out['choices'][0]['message']['content'].strip('` \n').strip('json\n'))['ingredients']
# Out:
# ['Beef Shank',
#  'Celery',
#  'Carrots',
#  'Onions',
#  'Garlic',
#  'Bay Leaf',
#  'Fresh Thyme',
#  'Olive Oil',
#  'Butter',
#  'Baguette',
#  'Salt',
#  'Black Pepper',
#  'Tomato Paste']

# %%
out['choices'][0]['message']['content'].strip('` \n').strip('json\n')
# Out:
# '{\n  "ingredients": [\n    "Beef Shank",\n    "Celery",\n    "Carrots",\n    "Onions",\n    "Garlic",\n    "Bay Leaf",\n    "Fresh Thyme",\n    "Olive Oil",\n    "Butter",\n    "Baguette",\n    "Salt",\n    "Black Pepper",\n    "Tomato Paste"\n  ]\n}'
